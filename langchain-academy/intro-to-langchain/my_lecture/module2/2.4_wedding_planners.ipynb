# %%
from dotenv import load_dotenv

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ## Setup Tools

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    **여행사(트래블 에이전트)**입니다. 사용자가 원하는 **결혼식 목적지(웨딩 장소)**로 가는 항공편을 검색하세요.
    다음 조건에 따라 최적의 항공편 옵션을 찾아야 하며, 추가 질문(후속 질문)은 절대 하면 안 됩니다. 아래 기준을 종합해 가장 좋은 항공편 옵션을 찾으세요.
    - 가격: 가장 저렴한 항공권(이코노미 클래스)
    - 소요 시간: 가장 짧은 총 이동 시간(최단)
    - 날짜: 해당 목적지에서 결혼식을 진행하기에 가장 적합하다고 판단되는 계절/시기
    
    작업을 단순화하기 위해 다음을 준수하세요.
    - 항공권 1장
    - 편도(one-way)
    - 성인 1인 기준
    
    최적의 결과를 얻기 위해 여러 번 검색을 반복하며 후보를 좁혀도 됩니다.
    사용자에게는 추가 정보가 제공되지 않습니다. 오직 **출발지(origin)**와 **도착지(destination)**만 주어집니다. 주어진 정보만으로 비판적으로 판단하여 최선의 항공편을 찾아내는 것이 당신의 역할입니다.
    최적의 결과를 찾은 뒤, 사용자에게 **추천 항공편 후보(쇼트리스트)**를 정리해 알려주세요.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    당신은 행사장(베뉴) 전문 컨설턴트입니다. 사용자가 원하는 지역과 수용 인원에 맞는 행사장(베뉴)을 검색하세요.
    추가 질문(후속 질문)은 절대 하면 안 됩니다. 아래 기준을 바탕으로 가장 좋은 행사장 옵션을 반드시 찾아야 합니다.
    - 가격: 가장 저렴한 곳(최저가)
    - 수용 인원: 사용자가 원하는 인원과 정확히 일치(정원 정확 일치)
    - 리뷰: 평점/후기가 가장 좋은 곳(최고 평가)
    최적의 결과를 얻기 위해 여러 번 검색을 반복하며 후보를 점진적으로 좁혀도 됩니다.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    당신은 플레이리스트(음악 큐레이션) 전문가입니다. 주어진 **장르(genre)**를 기반으로 SQL 데이터베이스를 조회하여 결혼식에 어울리는 완벽한 플레이리스트를 큐레이션하세요.
    플레이리스트를 구성한 뒤에는 다음을 수행해야 합니다.
    - 플레이리스트의 **총 재생 시간(전체 곡 길이 합계)**을 계산하세요.
    - 각 곡에는 가격이 연결되어 있으므로, 플레이리스트의 **총 비용(전체 곡 가격 합계)**도 계산하세요.
    
    데이터베이스를 조회하는 과정에서 오류가 발생하면 쿼리의 문법/조건/구조를 수정하여 오류를 해결하고 다시 시도하세요.
    빈손으로 돌아오면 안 됩니다.
    - 반드시 곡 리스트를 찾을 때까지 데이터베이스 조회를 계속 시도하세요.
    - 결과가 나올 때까지 쿼리를 반복적으로 개선하며 재조회하세요.
    최적의 결과를 얻기 위해 여러 번의 SQL 쿼리를 수행하면서 후보를 점진적으로 좁혀도 됩니다.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre"""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    당신은 웨딩 코디네이터입니다. 항공권, 행사장(베뉴), 플레이리스트를 담당하는 전문가들에게 업무를 위임하세요.
    먼저 상태(state)를 업데이트하기 위해 필요한 모든 정보를 수집하세요. 
    추가 질문(후속 질문)은 절대 하면 안 됩니다.
    필요한 정보 수집이 완료된 후 각 전문가에게 업무를 위임할 수 있습니다.
    각 전문가로부터 답변을 받은 뒤, 그 결과를 종합하여 나를 위한 완벽한 결혼식 계획을 조율하고 제안하세요.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="저는 런던에 살고 있고, 파리에서 하객 100명 규모로 jazz 장르 음악으로 결혼식을 하고 싶어요.")],
    }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'Jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content='저는 런던에 살고 있고, 파리에서 하객 100명 규모로 jazz 장르 음악으로 결혼식을 하고 싶어요.', additional_kwargs={}, response_metadata={}, id='ff31ebac-20cf-420e-9758-5329a77cb36c'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 868, 'prompt_tokens': 371, 'total_tokens': 1239, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D6udpFZopj4FOw8ZyBDF74hUMMd3P', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c69-6c99-7ba1-86b2-2ac838f97960-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'Jazz'}, 'id': 'call_OFaS8s8evBk5oTorA5viui5m', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 371, 'output_tokens': 868, 'total_tokens': 1239, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='47144c1e-2425-4977-8e72-43c4fcf90fd8', tool_call_id='call_OFaS8s8evBk5oTorA5viui5m'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 318, 'prompt_tokens': 415, 'total_tokens': 733, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D6udwUFcJMyYccpMM1izMvzxohyhe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c69-87b4-78c0-9f93-243edfc7c889-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_kQltOvCiKqcR2rZJ0wUaZnUn', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': 'call_0JMwRKpXIC2EmBWYHzFXaxYR', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_nk721aCjmq5QrKkEQPyXcOwj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 415, 'output_tokens': 318, 'total_tokens': 733, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#               ToolMessage(content='다음은 런던(London)에서 파리(Paris)까지의 편도 이코노미 항공권 후보를 요약한 결과입니다. 출발지는 여러 런던 공항(LHR, LGW, STN, LTN, SEN 등)에서 파리의 CDG 또는 ORY로 가는 옵션을 포함하고 있습니다. 가격은 EUR로 표기되며, 각 항공편의 목적지 공항과 현지 출발/도착 시간은 항공편 데이터에 따른 값입니다. 모든 항공권은 성인 1인, 1회 편도, 이코노미로 구성되어 있습니다.\n\n가장 저렴한(가격별 그룹) 후보\n- LHR → ORY (직항)\n  - 01/06/2026: 15:00(현지) → 17:35(현지), 약 1h35m, 51 EUR\n  - 예매 링크: https://on.kiwi.com/9hH1HT\n- LHR → ORY (직항)\n  - 01/10/2026: 15:00(현지) → 17:35(현지), 약 1h35m, 48 EUR\n  - 예매 링크: https://on.kiwi.com/am4W0h\n- LHR → ORY (직항)\n  - 15/09/2026: 15:00(현지) → 17:35(현지), 약 1h35m, 51 EUR\n  - 예매 링크: https://on.kiwi.com/bqnOtW\n- LTN → CDG (직항)\n  - 01/06/2026: 19:40(현지) → 22:00(현지), 약 1h20m, 53 EUR\n  - 예매 링크: https://on.kiwi.com/Wwjuqa\n\n가장 짧은 소요 시간(총 비행 시간 기준) 후보\n- STN → CDG (직항)\n  - 15/05/2026: 17:00(현지) → 19:10(현지), 약 1h10m, 59 EUR\n  - 예매 링크: https://on.kiwi.com/wIFMs3\n- LGW → CDG (직항)\n  - 01/10/2026: 18:00(현지) → 19:20(현지), 약 1h20m, 68 EUR\n  - 예매 링크: https://on.kiwi.com/kqENEN\n- LHR → ORY (직항)\n  - 01/10/2026: 15:00(현지) → 17:35(현지), 약 1h35m, 48 EUR\n  - 예매 링크: https://on.kiwi.com/am4W0h\n\n다른 후보들(참고용)\n- LTN → CDG (직항)\n  - 01/06/2026: 18:40(현지) → 22:00(현지), 약 1h20m, 53 EUR\n  - 예매 링크: https://on.kiwi.com/Wwjuqa\n- LGW → CDG (직항)\n  - 01/06/2026: 19:40(현지) → 22:00(현지), 약 1h20m, 57–59 EUR 대\n  - 예매 링크: 여러 항목\n- LHR → ORY (직항)\n  - 15/09/2026: 14:00(현지) → 15:35(현지), 약 1h35m, 51 EUR\n  - 예매 링크: https://on.kiwi.com/bqnOtW\n\n요약 및 추천\n- 추천 항공편(가성비 + 웨딩 시즌 적합성 관점)\n  - LHR → ORY, 01/06/2026, 15:00 → 17:35(현지), 약 1h35m, 51 EUR\n  - 이유: 같은 시즌(초여름) 동안 가장 저렴한 편이며, 직항으로 소요 시간이 짧고 파리에 무리 없이 도착합니다. 웨딩 시즌인 5–6월의 파리는 특히 쾌적합니다.\n\n- 보너스 팁\n  - 01/10/2026에 같은 루트의 저렴한 옵션도 있지만, 01/06의 51 EUR 옵션이 1년 안의 웨딩 시즌에 더 적합한 시점으로 간주될 수 있습니다. 원하시면 May–June 또는 Sep–Oct 중 특정 주를 겨냥해 더 최적화된 옵션을 추가로 찾아드릴 수 있습니다.\n\n마무리 인사 및 재미있는 파리 팁\n- 즐거운 여행 되시길 바랍니다! 파리는 로맨틱한 도시지만, 실용적인 면도 많습니다. 파리의 재미있는 사실 하나: 파리에는 세느강을 가로지르는 다리가 약 37개나 되어 도시를 여러 구간으로 나누는 매력을 더합니다. 파리에서의 웨딩 사진도 멋진 다리 아래에서 잘 어울리죠.\n\n추가로 원하시는 출발일 범위나 특정 공항 선호가 있다면 알려주시면, 그에 맞춰 더 구체적이고 최적화된 쇼트리스트를 바로 업데이트해 드리겠습니다.', name='search_flights', id='e04f3f79-4444-40da-9548-9860974420f6', tool_call_id='call_kQltOvCiKqcR2rZJ0wUaZnUn'),
#               ToolMessage(content='Here are Paris wedding venues that can accommodate exactly 100 guests, arranged from the lowest listed price to higher, with notes on capacity (seated vs. reception), and overall impression.\n\n- Château Barthélemy (Château Barthélemy, Lakeside Romantic Paris Wedding Venue)\n  - Capacity: 100 on-site\n  - Price: from €16,900 for 2 days, 1 night (as listed)\n  - Notes: Charming château setting near Paris; includes fixtures/furniture in the package. Strong option if you want a fairytale château feel at a relatively accessible price for the area.\n  - Source indicates 100-capacity and a starting price around €16.9k.\n\n- The Peninsula Paris\n  - Capacity: up to 100 guests for a seated dinner (in a grand ballroom setting)\n  - Price: venue hire from around €18,750 (pricing varies by package and date)\n  - Notes: Ultra-luxe, iconic Paris hotel with top-tier service and cuisine. High-end reviews and reputation; ideal if you want a glamorous city-center wedding with Eiffel Tower access nearby.\n  - Source notes: “Large, entirely soundproofed ballroom that can host up to 100 people for a sit-down dinner” and pricing references.\n\n- Four Seasons Hotel George V, Paris\n  - Capacity: up to 100 guests for receptions (seated dinner capacity varies by salon; often around 100 for a banquet)\n  - Price: not publicly published; typical premium-luxury pricing on request\n  - Notes: Among the most prestigious luxury hotels in Paris, famed for exceptional service, décor, and catering. If you’re aiming for a world-class luxury experience, this is a premier option.\n  - Source confirms up to 100 for receptions.\n\n- Hotel Marignan Champs-Elysées\n  - Capacity: up to 100 guests for cocktails/aperitifs; seated dinner capacity around 80\n  - Price: not publicly listed; premium pricing typical for this hotel\n  - Notes: Central, chic location with intimate to semi-formal reception spaces. Strong option if you want a stylish Champs-Élysées setting with tailored event planning.\n\n- (Alternative 100-cap options with cocktail-focused capacity)\n  - If you’re open to a 100-capacity for a cocktail-style reception (not a seated dinner), options like Hotel Concorde Paris or Hotel Le Marignan can be suitable. These venues often list 100-person cocktail capacities and premium service, though seated dinner capacities may be lower (e.g., around 80-100 depending on layout).\n\nImportant notes\n- If you require a strict seated dinner for 100, the Peninsula Paris and Four Seasons George V are the strongest options with confirmed 100-capacity seating in reputable luxury settings.\n- If you’re aiming for a château vibe at a comparatively lower starting price, Château Barthélemy offers a compelling 100-capacity package with a clearly listed starting price.\n- Exact final pricing will depend on your date, guest count, catering package, alcohol, and room rental inclusions. Quotes are typically provided on request by each venue.\n\nWould you like me to pull current, date-specific quotes for these venues or add a few more 100-capacity options (e.g., other near-Paris châteaux or private Paris venues) to compare?', name='search_venues', id='f11e0732-59a3-4c7e-8554-5531b9bee337', tool_call_id='call_0JMwRKpXIC2EmBWYHzFXaxYR'),
#               ToolMessage(content="좋아요! Jazz를 바탕으로 웨딩 플레이리스트를 선곡해 보았습니다. 아래는 데이터베이스에서 추출된 후보 중 분위기와 흐름을 고려한 15곡의 큐레이션안입니다. 곡 순서는 식전/식사 분위기에서 천천히 흐르다가 점차 살짝 업템포로 넘어가 dance 타임으로 이어지는 흐름을 의도했습니다.\n\n curated wedding Jazz playlist\n\n1) Garota De Ipanema — Antônio Carlos Jobim — 4:45 — $0.99\n2) Corcovado (Quiet Nights Of Quiet Stars) — Antônio Carlos Jobim — 3:25 — $0.99\n3) Desafinado — Antônio Carlos Jobim — 3:05 — $0.99\n4) Dindi — Antônio Carlos Jobim — 4:13 — $0.99\n5) Canta, Canta Mais — Antônio Carlos Jobim — 4:32 — $0.99\n6) Falando De Amor — Antônio Carlos Jobim — 3:40 — $0.99\n7) Samba De Uma Nota Só (One Note Samba) — Antônio Carlos Jobim — 2:17 — $0.99\n8) Fotografia — Antônio Carlos Jobim — 2:09 — $0.99\n9) Ligia — Antônio Carlos Jobim — 4:12 — $0.99\n10) Angela — Antônio Carlos Jobim — 2:50 — $0.99\n11) Outra Vez — Antônio Carlos Jobim — 2:06 — $0.99\n12) Por Causa De Você — Antônio Carlos Jobim — 2:50 — $0.99\n13) Se Todos Fossem Iguais A Você (Instrumental) — Antônio Carlos Jobim — 2:15 — $0.99\n14) Amanda — Aisha Duo — 4:07 — $0.99\n15) OAM's Blues — Aaron Goldberg — 4:27 — $0.99\n\n총 재생 시간: 약 50분 53초\n총 비용: 14.85 USD\n\n왜 이 구성이 웨딩에 잘 어울리나요\n- 분위기: Jobim의 보사노바/재즈 표준이 주를 이루어 로맨틱하고 가볍게 흐르는 분위기에 안성맞춤입니다.\n- 흐름: 식전이나 축하 대응 구간에 어울리는 느긋한 트랙으로 시작해, 중간에 살짝 가벼운 업템포 느낌의 곡과 잔잔한 보사노바를 섞어 자연스러운 대화와 분위기 전환을 돕습니다.\n- 다채로움: 남미 풍의 로맨틱한 곡들 사이에 Amanda(Aisha Duo)처럼 보사노바 외의 가벼운 재즈도 포인트로 섞어 다채로운 감성을 제공합니다.\n- 비용 효율: 전곡 0.99달러로 총 14.85달러의 합리적인 예산으로 구성했습니다.\n\n추가 조정 옵션\n- 더 길게 확장 원하시면: 1.5~2시간 분량으로 여러 곡(예: Billy Cobham 계열의 경쾌한 트랙, Gene Krupa의 스윙 트랙, Dennis Chambers의 파워 트랙 등)을 추가해 드릴 수 있습니다. 분위기를 더 활기차게 만들거나, 춤 시간대에 맞춘 6~8곡의 “댄스 블록”으로 구성해 드리겠습니다.\n- 특정 분위기 선호: 더 차분한 분위기(식전이나 예식 중간)로만 채우거나, 턴다운 없이 연속되는 재즈 스탠다드 위주로 재구성해 드릴 수 있습니다.\n- 언어/문화 취향: 포르투갈어 가사에 더 집중하거나, 영어/재즈 스탠더드 위주로 변경하는 것도 가능해요.\n\n원하시면 위 리스트를 기반으로 실제 재생 순서를 더 매끄럽게 다듬어 드리거나, 더 긴 확장판 버전을 만들어 드리겠습니다. 어떤 분위기나 길이로 맞춰 드릴까요?", name='suggest_playlist', id='c49f8d7b-7e66-498d-a966-b12b6595f53f', tool_call_id='call_nk721aCjmq5QrKkEQPyXcOwj'),
#               AIMessage(content="상태 업데이트 완료: 출발지 London, 도착지 Paris, 게스트 수 100명, 음악 장르 Jazz로 계획 중입니다.\n\n다음은 각 전문가에게 위임한 업무의 현재 상황 요약과 제안입니다. 추가 질문 없이 바로 실행 가능한 형태로 정리합니다.\n\n1) 항공권(Travel/항공권 전문가) 위임 결과 요약\n- 현재 제시된 대략적 그룹 항공 옵션이 있습니다. 주요 포인트\n  - LHR → ORY(파리 오를리) 직항 다수\n    - 예시 일정 1: 2026-01-06 15:00 → 17:35, 약 1h35m, 약 51 EUR\n    - 예시 일정 2: 2026-01-10 15:00 → 17:35, 약 1h35m, 약 48 EUR\n    - 예시 일정 3: 2026-09-15 15:00 → 17:35, 약 1h35m, 약 51 EUR\n  - LTN/LGW/STN 등 런던 인근 공항에서 CDG/ORY로의 대안 옵션도 포함\n    - STN → CDG: 2026-05-15 17:00 → 19:10, 약 1h10m, 약 59 EUR\n    - LGW → CDG: 2026-10-01 18:00 → 19:20, 약 1h20m, 약 68 EUR\n  - 요약: 파리의 ORY/CDG로의 직항 위주, 1시간 20–1시간 40분 내외의 비행 시간 및 48–68 EUR대의 편도 가격 후보 다수. 그룹 예약 시 5–6주 전후 여유를 두고 확정하는 방식이 일반적이며, 좌석 배치(100석 규모) 및 수하물 포함 여부에 따라 가격 차이가 생깁니다.\n- 위 제안은 현재 수집된 후보들로 구성되며, 최종 확정은 날짜(Wedding date), 도착/출발 분산 여부, 수하물 포함 여부, 좌석 블록 수 등에 따라 결정됩니다.\n- 담당 항공권 전문가에게 위임할 구체적 작업(요청 포맷 예시)\n  - 100명 규모의 그룹 항공 예약 패키지 제안: 최소 2개 날짜(예: 결혼식 전날 도착/당일 도착)로 나눠 견적 확보\n  - 좌석 배치: 같은 항공편에 가능한 한 다수의 게스트가 함께 도착하도록 묶기\n  - 공항-베뉴 간 수속 옵션: 그룹 체크인, 전용 버스/교통 수단 배치 견적 포함\n  - 수하물/식음료 선호 반영 및 취소 정책 명시\n  - 예산 범위와 일정에 맞춘 상향/하향 옵션 2–3안 제공\n  - 응답 포맷: 날짜/시간대, 항공사, 항공편 번호, 가격(총액 및 1인당 비용), 좌석 배치도, 예약 가능 상태, 취소/변경 정책 요약\n\n2) 행사장(베뉴) 위임 결과 요약\n- 제시된 파리 100명 수용이 가능한 상위 후보들:\n  - Chateau Barthélemy (Château Barthélémy)\n    - 수용: 100명 가능\n    - 시작가: 2일 1박 포함 패키지 약 €16,900\n    - 특징: 파리 인근의 전형적 동화 같은 성급 분위기, 예산 대비 매력적인 100인 규모 패키지\n  - The Peninsula Paris\n    - 수용: 최대 100명(좌식 디너 가능)\n    - 시작가: 약 €18,750(날짜/패키지에 따라 변동)\n    - 특징: 도심의 아이콘급 럭셔리, 대형 볼룸, 우수한 서비스/케이터링\n  - Four Seasons Hotel George V, Paris\n    - 수용: 100명 가능(살롱별 좌식 디너 규모는 다름)\n    - 가격: 공개 가격 비공개, 프리미엄급\n    - 특징: 세계적 수준의 서비스, 탁월한 케이터링, 럭셔리의 정점\n  - Hotel Marignan Champs-Elysées\n    - 수용: 칵테일/앱세트(100명) 가능, 좌식 디너는 보통 80명 선\n    - 가격: 공개되지 않음(프리미엄)\n    - 특징: 센트럴 위치, 모던하고 세련된 분위기\n  - 보조 옵션(대체/보완)\n    - 콘코드 파리, Le Marignan 등 100명 칵테일 수용 옵션\n- 현 상태의 제안 요약\n  - Seated 디너를 100명으로 확정하고자 한다면 Peninsula Paris와 Four Seasons George V가 가장 확실한 상용 옵션입니다.\n  - Château Barthélemy는 100인 수용 가능하고 시작가도 비교적 명확해 예산 대비 매력적일 수 있습니다.\n  - Hotel Marignan Champs-Elysées는 칵테일 중심의 리셉션이나 더 작게 묶인 좌석 구성이 필요할 때 좋습니다.\n- 담당 베뉴 전문가에게 위임할 구체적 작업(요청 포맷 예시)\n  - 2–3개의 후보에 대해 날짜별(예: 2026년 6월 혹은 9월의 특정 주) 구체 견적 요청\n  - 100명 좌석 디너 구성(스탠딩/시팅 레이아웃)과 가능 여부 확인\n  - 케이터링 옵션(One Service: 시저/샐러드/메인/디저트) 및 바 패키지 포함 여부와 가격 차이\n  - 대관료, 포함 항목(장비, 조명, 음악 시스템, 무대 등), 예약 취소 정책\n  - 응답 포맷: 날짜/시간, 면적/룸 이름, 좌석 구성(수용인원/배치도), 기본 가격, 포함 내역, 추가 옵션 가격, 예약 가능 여부\n\n3) 플레이리스트/뮤직 위임 결과 요약\n- 제안된 재즈 플레리스트(Wedding Jazz 스타일의 큐레이션 예시)\n  - 분위기 구분 제안: Ceremony(잔잔한 재즈/보사노바 분위기) → Cocktail Hour(활기 있는 스윙/보사노바) → Dinner(클래식 재즈 스탠더드) → Dancing(에너지 높은 재즈/스윙)\n  - 트랙 예시(리스트의 핵심 포함)\n    - Garota De Ipanema – Antonio Carlos Jobim\n    - Corcovado (Quiet Nights Of Quiet Stars) – Jobim\n    - Desafinado – Jobim\n    - Dindi – Jobim\n    - Samba De Uma Nota Sô (One Note Samba) – Jobim\n    - Fotografia – Jobim\n    - Ligia – Jobim\n    - Amanda – Aisha Duo\n    - OAM's Blues – Aaron Goldberg\n    - Outra Vez – Jobim\n    - Por Causa De Você – Jobim\n  - 길이/가격: 각 곡당 다운로드/스트리밍 비용 표기, 대략적인 세트 구성 및 길이 제시\n- 담당 음악/플레이리스트 전문가에게 위임할 구체적 작업(요청 포맷 예시)\n  - 예식 흐름에 맞춘 최적의 플레이리스트 확정( Ceremony, Cocktail, Dinner, Dance의 4파트 구분)\n  - 100명 규모의 공간에서 소리 밸런스(공간 음향)에 맞춘 구성\n  - 라이브 밴드(재즈 트리오/데스크) 대안 제시 및 예산 범위 내 실현 가능성 평가\n  - 추가적으로 필요한 악기 구성(피아노, 더블베이스, 색소폰 등) 및 레퍼토리 확장 제안\n  - 응답 포맷: 트랙 목록(필수 트랙, 대체 트랙 포함), 파트별 예상 길이, 필요 장비/스태프 여부, 예산 제안\n\n다음으로 제안하는 종합 웨딩 플랜(권장 옵션 포함)\n- 최적 조합 A: 럭셔리 시티-럭스 옵션\n  - 베뉴: The Peninsula Paris(100석까지 가능) 또는 Four Seasons George V 중 선택\n  - 항공권: 그룹 항공권 전문가가 100명 규모의 도착/출발 일정 최적화 및 단일/복수 편 예약 구성\n  - 음악: 재즈 스탠더드 중심의 4파트 플레이리스트 구성, 필요 시 라이브 트리오/DJ 병합\n  - 분위기: 도심의 화려함+섬세한 서비스, 케이터링과 룸 구성의 완벽한 매칭\n  - 예상 포인트: 럭셔리한 사진/영상 배경, Eiffel Tower 인근 위치로의 사진/투어 연계 가능\n- 최적 조합 B: Château Barthélémy 기반의 페어리테일 분위기\n  - 베뉴: Château Barthélémy(100명 수용, 패키지 시작가 약 €16,900)\n  - 항공권: 런던-파리 간 그룹 도착 옵션과 현지 교통 연결\n  - 음악: 보사노바+클래식 재즈의 조화로 고전적이면서도 친근한 분위기\n  - 분위 ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# 상태 업데이트 완료: 출발지 London, 도착지 Paris, 게스트 수 100명, 음악 장르 Jazz로 계획 중입니다.
#
# 다음은 각 전문가에게 위임한 업무의 현재 상황 요약과 제안입니다. 추가 질문 없이 바로 실행 가능한 형태로 정리합니다.
#
# 1) 항공권(Travel/항공권 전문가) 위임 결과 요약
# - 현재 제시된 대략적 그룹 항공 옵션이 있습니다. 주요 포인트
#   - LHR → ORY(파리 오를리) 직항 다수
#     - 예시 일정 1: 2026-01-06 15:00 → 17:35, 약 1h35m, 약 51 EUR
#     - 예시 일정 2: 2026-01-10 15:00 → 17:35, 약 1h35m, 약 48 EUR
#     - 예시 일정 3: 2026-09-15 15:00 → 17:35, 약 1h35m, 약 51 EUR
#   - LTN/LGW/STN 등 런던 인근 공항에서 CDG/ORY로의 대안 옵션도 포함
#     - STN → CDG: 2026-05-15 17:00 → 19:10, 약 1h10m, 약 59 EUR
#     - LGW → CDG: 2026-10-01 18:00 → 19:20, 약 1h20m, 약 68 EUR
#   - 요약: 파리의 ORY/CDG로의 직항 위주, 1시간 20–1시간 40분 내외의 비행 시간 및 48–68 EUR대의 편도 가격 후보 다수. 그룹 예약 시 5–6주 전후 여유를 두고 확정하는 방식이 일반적이며, 좌석 배치(100석 규모) 및 수하물 포함 여부에 따라 가격 차이가 생깁니다.
# - 위 제안은 현재 수집된 후보들로 구성되며, 최종 확정은 날짜(Wedding date), 도착/출발 분산 여부, 수하물 포함 여부, 좌석 블록 수 등에 따라 결정됩니다.
# - 담당 항공권 전문가에게 위임할 구체적 작업(요청 포맷 예시)
#   - 100명 규모의 그룹 항공 예약 패키지 제안: 최소 2개 날짜(예: 결혼식 전날 도착/당일 도착)로 나눠 견적 확보
#   - 좌석 배치: 같은 항공편에 가능한 한 다수의 게스트가 함께 도착하도록 묶기
#   - 공항-베뉴 간 수속 옵션: 그룹 체크인, 전용 버스/교통 수단 배치 견적 포함
#   - 수하물/식음료 선호 반영 및 취소 정책 명시
#   - 예산 범위와 일정에 맞춘 상향/하향 옵션 2–3안 제공
#   - 응답 포맷: 날짜/시간대, 항공사, 항공편 번호, 가격(총액 및 1인당 비용), 좌석 배치도, 예약 가능 상태, 취소/변경 정책 요약
#
# 2) 행사장(베뉴) 위임 결과 요약
# - 제시된 파리 100명 수용이 가능한 상위 후보들:
#   - Chateau Barthélemy (Château Barthélémy)
#     - 수용: 100명 가능
#     - 시작가: 2일 1박 포함 패키지 약 €16,900
#     - 특징: 파리 인근의 전형적 동화 같은 성급 분위기, 예산 대비 매력적인 100인 규모 패키지
#   - The Peninsula Paris
#     - 수용: 최대 100명(좌식 디너 가능)
#     - 시작가: 약 €18,750(날짜/패키지에 따라 변동)
#     - 특징: 도심의 아이콘급 럭셔리, 대형 볼룸, 우수한 서비스/케이터링
#   - Four Seasons Hotel George V, Paris
#     - 수용: 100명 가능(살롱별 좌식 디너 규모는 다름)
#     - 가격: 공개 가격 비공개, 프리미엄급
#     - 특징: 세계적 수준의 서비스, 탁월한 케이터링, 럭셔리의 정점
#   - Hotel Marignan Champs-Elysées
#     - 수용: 칵테일/앱세트(100명) 가능, 좌식 디너는 보통 80명 선
#     - 가격: 공개되지 않음(프리미엄)
#     - 특징: 센트럴 위치, 모던하고 세련된 분위기
#   - 보조 옵션(대체/보완)
#     - 콘코드 파리, Le Marignan 등 100명 칵테일 수용 옵션
# - 현 상태의 제안 요약
#   - Seated 디너를 100명으로 확정하고자 한다면 Peninsula Paris와 Four Seasons George V가 가장 확실한 상용 옵션입니다.
#   - Château Barthélemy는 100인 수용 가능하고 시작가도 비교적 명확해 예산 대비 매력적일 수 있습니다.
#   - Hotel Marignan Champs-Elysées는 칵테일 중심의 리셉션이나 더 작게 묶인 좌석 구성이 필요할 때 좋습니다.
# - 담당 베뉴 전문가에게 위임할 구체적 작업(요청 포맷 예시)
#   - 2–3개의 후보에 대해 날짜별(예: 2026년 6월 혹은 9월의 특정 주) 구체 견적 요청
#   - 100명 좌석 디너 구성(스탠딩/시팅 레이아웃)과 가능 여부 확인
#   - 케이터링 옵션(One Service: 시저/샐러드/메인/디저트) 및 바 패키지 포함 여부와 가격 차이
#   - 대관료, 포함 항목(장비, 조명, 음악 시스템, 무대 등), 예약 취소 정책
#   - 응답 포맷: 날짜/시간, 면적/룸 이름, 좌석 구성(수용인원/배치도), 기본 가격, 포함 내역, 추가 옵션 가격, 예약 가능 여부
#
# 3) 플레이리스트/뮤직 위임 결과 요약
# - 제안된 재즈 플레리스트(Wedding Jazz 스타일의 큐레이션 예시)
#   - 분위기 구분 제안: Ceremony(잔잔한 재즈/보사노바 분위기) → Cocktail Hour(활기 있는 스윙/보사노바) → Dinner(클래식 재즈 스탠더드) → Dancing(에너지 높은 재즈/스윙)
#   - 트랙 예시(리스트의 핵심 포함)
#     - Garota De Ipanema – Antonio Carlos Jobim
#     - Corcovado (Quiet Nights Of Quiet Stars) – Jobim
#     - Desafinado – Jobim
#     - Dindi – Jobim
#     - Samba De Uma Nota Sô (One Note Samba) – Jobim
#     - Fotografia – Jobim
#     - Ligia – Jobim
#     - Amanda – Aisha Duo
#     - OAM's Blues – Aaron Goldberg
#     - Outra Vez – Jobim
#     - Por Causa De Você – Jobim
#   - 길이/가격: 각 곡당 다운로드/스트리밍 비용 표기, 대략적인 세트 구성 및 길이 제시
# - 담당 음악/플레이리스트 전문가에게 위임할 구체적 작업(요청 포맷 예시)
#   - 예식 흐름에 맞춘 최적의 플레이리스트 확정( Ceremony, Cocktail, Dinner, Dance의 4파트 구분)
#   - 100명 규모의 공간에서 소리 밸런스(공간 음향)에 맞춘 구성
#   - 라이브 밴드(재즈 트리오/데스크) 대안 제시 및 예산 범위 내 실현 가능성 평가
#   - 추가적으로 필요한 악기 구성(피아노, 더블베이스, 색소폰 등) 및 레퍼토리 확장 제안
#   - 응답 포맷: 트랙 목록(필수 트랙, 대체 트랙 포함), 파트별 예상 길이, 필요 장비/스태프 여부, 예산 제안
#
# 다음으로 제안하는 종합 웨딩 플랜(권장 옵션 포함)
# - 최적 조합 A: 럭셔리 시티-럭스 옵션
#   - 베뉴: The Peninsula Paris(100석까지 가능) 또는 Four Seasons George V 중 선택
#   - 항공권: 그룹 항공권 전문가가 100명 규모의 도착/출발 일정 최적화 및 단일/복수 편 예약 구성
#   - 음악: 재즈 스탠더드 중심의 4파트 플레이리스트 구성, 필요 시 라이브 트리오/DJ 병합
#   - 분위기: 도심의 화려함+섬세한 서비스, 케이터링과 룸 구성의 완벽한 매칭
#   - 예상 포인트: 럭셔리한 사진/영상 배경, Eiffel Tower 인근 위치로의 사진/투어 연계 가능
# - 최적 조합 B: Château Barthélémy 기반의 페어리테일 분위기
#   - 베뉴: Château Barthélémy(100명 수용, 패키지 시작가 약 €16,900)
#   - 항공권: 런던-파리 간 그룹 도착 옵션과 현지 교통 연결
#   - 음악: 보사노바+클래식 재즈의 조화로 고전적이면서도 친근한 분위기
#   - 분위기: 성급/목가적 분위기, 예산 대비 큰 임팩트 가능
# - 최적 조합 C: 칵테일 위주/도심형 세팅
#   - 베뉴: Hotel Marignan Champs-Elysées 또는 Hotel Concorde Paris
#   - 항공권: 그룹 옵션과 현지 교통의 간편성 강조
#   - 음악: 칵테일 시간대의 경쾌한 재즈/스윙 중심, 100명 규모의 칵테일 리셉션에 최적
#   - 분위기: 모던하고 세련된 파리 중심지에서의 네트워킹/리셉션에 적합
#
# 플래너로서의 운영 팁
# - 일정 제안: 게스트 100명을 고려해 도착일(전날)과 결혼식 당일, 그리고 파리에서의 간단한 시내 투어를 포함한 3일 일정으로 구상하는 것이 무난합니다. 다만 오늘의 정보로는 정확한 날짜를 확정하긴 어려우니, 위의 옵션 중 하나를 기준으로 그룹 예약 진행이 필요합니다.
# - 예산 관리: 베뉴/케이터링/오디오-비주얼/음악/플로리스트 등 주요 항목의 예산 비중을 미리 설정하고, 각 전문가는 그 범위 내에서 2–3안의 구체 견적을 제공하도록 합니다.
# - 커뮤니케이션 흐름: 항공권, 베뉴, 음악의 담당 전문가가 서로의 일정/제약을 공유하는 형태의 협업 체계를 구축하면 일정 조율이 매끄럽습니다.
#
# 지금까지의 결과를 바탕으로, 원하시는 분위기(럭셔리/전통적인 Château 분위기/도심 칵테일형)와 예산 범위를 최우선으로 최적의 조합을 하나로 좁히는 방향으로 진행하겠습니다. 원하시는 최종 방향(예: 럭셔리 시티 옵션으로 확정, Château 분위기 우선 등)을 알려주시면, 각 전문팀이 즉시 구체 견적과 실행 로드맵을 드리도록 하겠습니다.
#
# 필요 시, 각 전문가에게 전달할 구체 요청 포맷(날짜 범위, 게스트 구성, 예산 상한선 등)을 제가 바로 정리해 드릴 수 있습니다. 원하시는 분위기와 예산 범위를 알려주시면 바로 반영하겠습니다.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
