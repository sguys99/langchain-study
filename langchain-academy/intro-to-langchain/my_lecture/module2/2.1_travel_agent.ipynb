# %%
from dotenv import load_dotenv

load_dotenv("../../.env")
# Out:
# False

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions." # 사용자에게 추가 질문을 하지 말고, 바로 답을 내라는 지시
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='99816132-b517-41f6-a43c-721b9ab553f3'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1161, 'prompt_tokens': 1229, 'total_tokens': 2390, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1088, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D5L5zZY32EqaRk1uZzXnyjrmMVm6p', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c260f-ebb9-7281-a830-f74e311651b3-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'departureDateFlexRange': 0, 'passengers': {'adults': 1}, 'cabinClass': 'M', 'curr': 'USD', 'locale': 'en', 'sort': 'price'}, 'id': 'call_rk5qoj8tiScyr3RERzR2yHo7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 1161, 'total_tokens': 2390, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1088}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-04-01T02:32:00.000Z",\n      "local": "2026-03-31T19:32:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T05:25:00.000Z",\n      "local": "2026-04-02T14:25:00.000"\n    },\n    "totalDurationInSeconds": 96780,\n    "durationInSeconds": 96780,\n    "price": 440,\n    "deepLink": "https://on.kiwi.com/GhDFIS",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "LAS",\n        "city": "Las Vegas",\n        "cityCode": "LAS",\n        "arrival": {\n          "utc": "2026-04-01T04:14:00.000Z",\n          "local": "2026-03-31T21:14:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T08:01:00.000Z",\n          "local": "2026-04-01T01:01:00.000"\n        }\n      },\n      {\n        "at": "IAH",\n        "city": "Houston",\n        "cityCode": "HOU",\n        "arrival": {\n          "utc": "2026-04-01T10:52:00.000Z",\n          "local": "2026-04-01T05:52:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T15:25:00.000Z",\n          "local": "2026-04-01T10:25:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:25:00.000Z",\n      "local": "2026-04-01T19:25:00.000"\n    },\n    "totalDurationInSeconds": 95700,\n    "durationInSeconds": 95700,\n    "price": 492,\n    "deepLink": "https://on.kiwi.com/ThwsQc",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:25:00.000Z",\n          "local": "2026-04-01T05:25:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T07:00:00.000Z",\n          "local": "2026-04-01T15:00:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T20:00:00.000Z",\n      "local": "2026-03-31T13:00:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T21:50:00.000Z",\n      "local": "2026-04-02T06:50:00.000"\n    },\n    "totalDurationInSeconds": 93000,\n    "durationInSeconds": 93000,\n    "price": 511,\n    "deepLink": "https://on.kiwi.com/qQVD0q",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "HKG",\n        "city": "Hong Kong",\n        "cityCode": "HKG",\n        "arrival": {\n          "utc": "2026-04-01T10:55:00.000Z",\n          "local": "2026-04-01T18:55:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T17:20:00.000Z",\n          "local": "2026-04-02T01:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T20:00:00.000Z",\n      "local": "2026-03-31T13:00:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T07:05:00.000Z",\n      "local": "2026-04-02T16:05:00.000"\n    },\n    "totalDurationInSeconds": 126300,\n    "durationInSeconds": 126300,\n    "price": 511,\n    "deepLink": "https://on.kiwi.com/hyFnOb",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "HKG",\n        "city": "Hong Kong",\n        "cityCode": "HKG",\n        "arrival": {\n          "utc": "2026-04-01T10:55:00.000Z",\n          "local": "2026-04-01T18:55:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T02:40:00.000Z",\n          "local": "2026-04-02T10:40:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo" ...
#               AIMessage(content='Here are direct SFO to Tokyo flights on March 31, 2026.\n\nCheapest options (by price)\n| Route | Schedule (local) | Cabin | Price (USD) | Deep link |\n|---|---|---|---:|---|\n| SFO → NRT | 03/31 16:45 → 04/01 11:00 (11h15m) | Economy | 572 | https://on.kiwi.com/ja0HUe |\n\nShortest duration options\n| Route | Schedule (local) | Cabin | Price (USD) | Deep link |\n|---|---|---|---:|---|\n| SFO → NRT | 03/31 12:20 → 04/01 15:25 (11h05m) | Economy | 1261 | https://on.kiwi.com/PJeniu |\n\nOther interesting options\n| Route | Schedule (local) | Cabin | Price (USD) | Deep link |\n|---|---|---|---:|---|\n| SFO → NRT | 03/31 11:40 → 04/01 15:00 (11h20m) | Economy | 1047 | https://on.kiwi.com/GVRABI |\n\nSummary\n- Best price: 572 USD (direct, 11h15m)\n- Shortest direct flight: 11h05m (1261 USD)\n- Recommendation: If you want the lowest fare, go with the 572 USD direct option. If you prefer the shortest duration, the 11h05m option at 1261 USD is best among direct flights.\n\nHave a great trip! Fun fact: Tokyo has more Michelin-starred restaurants than any other city in the world.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5689, 'prompt_tokens': 6224, 'total_tokens': 11913, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 5312, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D5L6B4Hgc5ttEMfXuWHJh0bF34n2Y', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c2610-1b2a-7f52-8af5-910a1cf0f716-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6224, 'output_tokens': 5689, 'total_tokens': 11913, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 5312}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct SFO to Tokyo flights on March 31, 2026.
#
# Cheapest options (by price)
# | Route | Schedule (local) | Cabin | Price (USD) | Deep link |
# |---|---|---|---:|---|
# | SFO → NRT | 03/31 16:45 → 04/01 11:00 (11h15m) | Economy | 572 | https://on.kiwi.com/ja0HUe |
#
# Shortest duration options
# | Route | Schedule (local) | Cabin | Price (USD) | Deep link |
# |---|---|---|---:|---|
# | SFO → NRT | 03/31 12:20 → 04/01 15:25 (11h05m) | Economy | 1261 | https://on.kiwi.com/PJeniu |
#
# Other interesting options
# | Route | Schedule (local) | Cabin | Price (USD) | Deep link |
# |---|---|---|---:|---|
# | SFO → NRT | 03/31 11:40 → 04/01 15:00 (11h20m) | Economy | 1047 | https://on.kiwi.com/GVRABI |
#
# Summary
# - Best price: 572 USD (direct, 11h15m)
# - Shortest direct flight: 11h05m (1261 USD)
# - Recommendation: If you want the lowest fare, go with the 572 USD direct option. If you prefer the shortest duration, the 11h05m option at 1261 USD is best among direct flights.
#
# Have a great trip! Fun fact: Tokyo has more Michelin-starred restaurants than any other city in the world.
