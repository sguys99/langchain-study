# %% [markdown]
# ## 1.1 foundateion_models

# %%
from dotenv import load_dotenv

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")
model
# Out:
# ChatOpenAI(profile={'max_input_tokens': 272000, 'max_output_tokens': 128000, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x10f5f2d20>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x118f319a0>, root_client=<openai.OpenAI object at 0x10f017bc0>, root_async_client=<openai.AsyncOpenAI object at 0x118389670>, model_name='gpt-5-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
response = model.invoke("달의 수도는 어디야?")

response
# Out:
# AIMessage(content='달에는 수도가 없어요. 수도는 보통 한 나라의 행정 중심 도시를 뜻하는데, 달은 독립된 정부나 주권이 없고 행정 구역도 없기 때문입니다. 다만 소설이나 게임 같은 설정에서는 “수도”를 붙일 수는 있는데, 현실엔 존재하지 않습니다. 참고로 현재 달에 공식적인 거주 도시나 기지는 없고, 미래에 상주 기지 논의가 있긴 하지만 수도의 개념은 없습니다.\n\n다른 맥락에서 궁금한 게 있나요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 832, 'prompt_tokens': 13, 'total_tokens': 845, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtU6ZxgtY821Hypy68fpA0BzO2qUF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b7da9-2d63-7860-a604-537184fd000b-0', usage_metadata={'input_tokens': 13, 'output_tokens': 832, 'total_tokens': 845, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})

# %%
print(response.content)
# Out:
# 달에는 수도가 없어요. 수도는 보통 한 나라의 행정 중심 도시를 뜻하는데, 달은 독립된 정부나 주권이 없고 행정 구역도 없기 때문입니다. 다만 소설이나 게임 같은 설정에서는 “수도”를 붙일 수는 있는데, 현실엔 존재하지 않습니다. 참고로 현재 달에 공식적인 거주 도시나 기지는 없고, 미래에 상주 기지 논의가 있긴 하지만 수도의 개념은 없습니다.
#
# 다른 맥락에서 궁금한 게 있나요?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-CtU6ZxgtY821Hypy68fpA0BzO2qUF',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 832,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 704,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 845}}

# %% [markdown]
# ### 모델 커스터마이징 하기

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("달의 수도는 어디야?")
print(response.content)
# Out:
# 달에는 수도가 없어요. 달은 국가나 주권이 없는 천체이기 때문에 공식적인 행정 수도가 존재하지 않습니다. 다만 공상과학이나 소설에서 ‘달의 수도’를 상상하는 경우가 있는데, 예를 들면 루나폴리스(Lunapolis) 같은 이름이 자주 쓰이곤 합니다. 원하시면 상상의 수도 이름을 몇 가지 더 지어 드릴게요. 어떤 분위기의 이름을 원하시나요?

# %% [markdown]
# ### 모델 제공사

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("달의 수도는 어디야?")
print(response.content)
# Out:
# 달(Moon)은 지구의 자연 위성이기 때문에 수도가 없습니다. 달에는 인간이 상주하는 도시나 정착지가 없으며, 현재까지 무인 탐사선과 과거 아폴로 미션에서 우주비행사들이 잠깐 방문했을 뿐입니다.
#
# 혹시 다른 의미로 질문하신 건가요? 예를 들어:
# - 특정 국가나 지역의 이름이 "달"과 비슷한 경우
# - SF 작품 속 달 기지의 이름
#
# 더 구체적으로 말씀해 주시면 정확한 답변을 드릴 수 있습니다.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("달의 수도는 어디야?")
print(response.content)
# Out:
# 달에는 수도가 없습니다. 달은 지구의 위성이며, 지구처럼 국가나 도시가 존재하지 않습니다.
#
# 지금까지 인류가 달에 착륙하여 탐사 활동을 하긴 했지만, 달에 영구적인 거주지나 정부 기구는 아직 건설되지 않았습니다.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model) # 여기서는 구글 모델

# %%
agent = create_agent(model="claude-sonnet-4-5") # 이런 식의 설정도 가능

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="달의 수도는 어디야?")]} # 메시지가 담긴 딕셔너리를 보내고, 그것이 사용자로 부터 왔음을 표시
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='달의 수도는 어디야?', additional_kwargs={}, response_metadata={}, id='af2e35bb-1cc7-4d99-b0a7-049111ba18bb'),
#               AIMessage(content='달에는 수도가 없어요. 달은 지구의 위성이며 현재 인구나 정부가 없어서 아무 나라의 수도도 아닙니다. 앞으로 거주 기지가 생겨도 어떤 국가나 국제 합의하에 정해질 문제이지 아직은 존재하지 않는 상태예요.\n\n참고로 재미로 상상하면 소설이나 영화에서 "루나폴리스(Lunapolis)" 같은 이름의 수도를 붙이기도 해요. 다른 궁금한 점이 있으면 또 물어보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1014, 'prompt_tokens': 13, 'total_tokens': 1027, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtUAxxOhQtzBuKSXWxnYum1RLCVf5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b7dad-577a-77f1-8cf5-ec69e507c54f-0', usage_metadata={'input_tokens': 13, 'output_tokens': 1014, 'total_tokens': 1027, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}})]}

# %%
print(response['messages'][-1].content)
# Out:
# 달에는 수도가 없어요. 달은 지구의 위성이며 현재 인구나 정부가 없어서 아무 나라의 수도도 아닙니다. 앞으로 거주 기지가 생겨도 어떤 국가나 국제 합의하에 정해질 문제이지 아직은 존재하지 않는 상태예요.
#
# 참고로 재미로 상상하면 소설이나 영화에서 "루나폴리스(Lunapolis)" 같은 이름의 수도를 붙이기도 해요. 다른 궁금한 점이 있으면 또 물어보세요!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="달의 수도는 어디야?"),
    AIMessage(content="달의 수도는 Luna City입니다."),
    HumanMessage(content="재미있네요, Luna City에 대해서 더 알려주세요.")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='달의 수도는 어디야?', additional_kwargs={}, response_metadata={}, id='13bcd8ea-5247-4b4f-abc4-d4172316fe11'),
#               AIMessage(content='달의 수도는 Luna City입니다.', additional_kwargs={}, response_metadata={}, id='b53e48f3-410c-48d9-ae34-5b3eb134958b'),
#               HumanMessage(content='재미있네요, Luna City에 대해서 더 알려주세요.', additional_kwargs={}, response_metadata={}, id='0e0219a6-4eee-4d2d-a5ce-432909798694'),
#               AIMessage(content='좋아요! Luna City는 달의 수도로 설정된 가상의 도시예요. 아래는 한 가지 섬세한 세계관 예시입니다. 필요하시면 분위기나 장르에 맞춰 더 다듬어 드릴게요.\n\n개요\n- 위치와 성격: 달의 안쪽 크레이터 가장자리와 인접한 지역에 자리한 거대 도시. 과학, 예술, 정치가 한자리에 모이는 국제적 허브이며, 지하 터널과 공중 도로로 서로 연결되어 있습니다.\n- 인구와 정치: 약 100만~150만 명이 거주하는 대도시로, 달 연방(Lunar Confederation)의 행정 중심이자 문화 수도입니다. 도시 의회와 행정 관리 기구가 함께 운영합니다.\n\n주요 구역과 특징\n- 크레이터 링(Crater Ring): 상업과 서비스가 몰려 있는 상업 지구. 식료품, 시장, 카페, 소매점이 모여 있습니다.\n- 거치대 돔(Trans-Dome District): 주거 지역과 연구실, 교육 시설이 한데 모인 거대 돔 단지. 자가 발전형 생태 농원과 수자원 재생 설비가 있습니다.\n- 빛의 타워(Glass Spire): 시청과 행정 시설이 집중된 도시의 심장부. 태양광과 반사 유리를 이용한 에너지 관리 시스템의 상징물입니다.\n- 예술의 광장(Arcade of Echoes): 공연장, 갤러리, 실험 미술관이 모여 있어 야간에 빛과 그림자가 어우러지는 분야별 축제가 자주 열립니다.\n- 빙점 마켓(Icepoint Market): 극지방에서 옮겨 온 물 자원과 우주 광물, 3D 프린팅 재료를 거래하는 무역 중심지.\n- 연구와 교육 구역: 우주탐사, 생체공학, 로봇공학, 에너지 관리 연구소가 밀집해 있어 학생과 연구자들이 활발히 왕래합니다.\n\n문화와 사회\n- 인구 구성: 지구 연방의 이주민, 연구원, 예술가, 엔지니어가 균형을 이루며, 인공지능(AI) 보조 시스템이 도시 운영에 깊숙이 관여합니다.\n- 언어와 소통: 지구 출신 언어에 달 특유의 용어가 섞인 ‘루나 크리올(Luna Creole)’ 같은 가상 언어가 공용으로 사용되기도 합니다.\n- 생활 방식: 14일 주기의 낮/밤에 맞춰 에너지 소비를 최적화하는 도시 에너지 관리 시스템이 작동합니다. 실내에서의 생활이 많아 실외 활동은 ‘생태 돔’과 ‘터널 공원’을 중심으로 이루어집니다.\n- 축제와 관습: 예를 들어 ‘일식 축제’(태양전지의 빛을 활용한 예술 공연)이나 ‘둥지의 밤’(생태 돔 안에서 열리는 음악과 빛의 축제) 같은 이벤트가 자주 열립니다.\n\n경제와 기술\n- 주요 산업: Helium-3 채굴과 물 저장/정화 기술, 우주식량 생산, 고도화된 3D 프린팅, 연구 개발 및 데이터 센터.\n- 에너지: 대형 태양광 배열과 반사 유리로 구성된 에너지 관리 시스템이 도시 전력의 다층 보안을 제공합니다.\n- 생활 기술: 공간 제약이 큰 달 환경에 맞춘 폐수 재생, 공기 순환, 온도 조절 시스템이 표준화되어 있습니다.\n\n교통과 인프라\n- 교통 수단: 진공튜브를 이용한 고속 모듈 운송, 저중력 도로를 다니는 마그네틱 트램, 개인용 로봇 팔목 드론 등으로 사람과 물자를 빠르게 이동합니다.\n- 물리적 특징: 미세먼지(먼지)와 진공 상태를 고려한 방호 시스템이 모든 실내 공간에 기본으로 설치됩니다.\n- 안전과 관리: 재난 대비 시스템, 방사선 차단, 방진 시설이 도시 전역에 표준화되어 있습니다.\n\n스토리 아이디어와 캐릭터 포지션\n- 정치가-과학자: 우주연방의 정책과 연구 개발 간의 균열을 다루는 긴장감.\n- 탐사대원-도시 수호대: 달 표면의 미지의 자원을 둘러싼 갈등과 협력.\n- 예술가-생태 디자이너: 돔 내부 생태계와 예술을 결합하는 혁신 프로젝트.\n- 일상 인물들: 냉각 기술 엔지니어, 시장 상인, 교통 제어사 등 도시의 일상을 구성하는 다양한 인물들.\n\n짧은 시나리오 훅\n- 크레이터 링의 야간 축제 도중 도시의 에너지 관리 시스템이 예기치 못한 사이버 침해를 받으면서 벌어지는 해킹 대치와 협력 이야기.\n- 빛의 타워에서 열리는 중요한 국제 협상 날, 플랫팩드 도구를 이용한 신기술이 폭우처럼 쏟아지는 빛과 그림자를 통해 발표하는 장면.\n- 물 자원 관리 돔에서 발견된 고대 버그가 실제로는 달의 기원에 연결된 비밀 데이터 피라미드를 암시하는 단서가 되는 미스터리.\n\n필요하시면 이 설정을 바탕으로:\n- 지도 아이디어(도시 축/크레이터 위치 구상)\n- 특정 장르에 맞춘 짧은 소개 글\n- 등장 인물 프로필 샘플\n을 만들어 드릴게요. 어떤 분위기로 발전시키고 싶으신가요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3090, 'prompt_tokens': 44, 'total_tokens': 3134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1792, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtUBztgHr7scMt6yxUmMERdYj4SC8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b7dae-54fb-77b1-b0cd-04d812d6bfa8-0', usage_metadata={'input_tokens': 44, 'output_tokens': 3090, 'total_tokens': 3134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1792}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="달의 수도인 Luna City에 대해서 알려주세요")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# 실제로 달의 수도로 불리는 도시가 현실에 존재하는 것은 아니고, Luna City라는 이름은 보통 SF 설정이나 게임에서 자주 쓰이는 가상의 도시 이름입니다. 원하신다면 특정 작품의 설정을 참고해 정리해 드리거나, 새로운 세계관으로 자세히 만들어 드릴 수 있습니다. 아래는 흔히 보이는 한 가지 유형의 Luna City 구성 예시입니다.
#
# 간단한 개요
# - 위치와 형태: 달의 음영이 많은 충돌구/돔도시로 구성되며, 표면은 거친 달 바람과 극심한 온도 변화를 피하기 위해 돔과 지하 네트워크로 생활합니다.
# - 주된 기능: 행정 중심지이자 경제 허브. 우주자원(물, 에너지, 광물) 확보와 연구개발의 중심지로서 Earth–Moon 협력의 상징이 됩니다.
# - 분위기: 다국적 커뮤니티가 어울려 살며, 첨단 기술과 인류의 적응력이 공존하는 미래적이면서도 현실적인 도시.
#
# 주요 구성 요소
# - 위치와 도시 구조
#   - 위치: 달의 근접면 또는 큰 크레이터 내부의 돔도시로, 연구소와 행정 구역이 집중된 중심부와 주거 지역이 이어지는 다층적 구조.
#   - 표면 life-support: 표면은 방사선과 극저온/고온의 극단적 환경이므로 주거와 산업은 돔과 지하 터널에 집중.
#   - 교통: 내부는 자율주행 택시, 자가부상 트램(마그레이브 모듈), 지하 터널망, 크레이터 간 수송 로켓/열차 등으로 연결됩니다.
#
# - 거버넌스와 사회 구조
#   - 거버넌스: Lunar Assembly(달 의회)와 각 거주 구역의 대표로 구성된 연합체. 국제 협력 체계 아래 Earth–Moon 협정에 따라 자원 관리와 연구 정책을 결정.
#   - 시민권: 거주 기간·생계 기여도에 따라 혜택이 다르며, 연구원, 엔지니어, 광물 상인 등 다양한 직군이 공존.
#   - 사회문화: 다국적·다문화 커뮤니티로, 언어와 문화가 혼합되어 있지만 공통의 생존 규범(물 관리, 에너지 절약, 우주 안전)이 중심.
#
# - 경제와 기술
#   - 주요 자원: 물 아이스, 헬륨-3 같은 우주자원, 지하의 광물, 재생 가능한 에너지(태양광+에너지 저장).
#   - 산업: 물 추출/정제, 생태계 모듈링(생산 시스템), 3D 프린팅으로 부품 생산, 우주선 부품 제조, 연구개발(R&D) 역량 집중.
#   - 일상 기술: 폐쇄 순환 사회로 공기 재생, 물 재생, 농업용 유리온실/생물 반응로를 통한 식량 생산.
#
# - 도시의 분위기와 문화
#   - 건축: 현무암 같은 달 표면 재료와 강화유리, 빛을 내는 결빙 소재, 어두운 외벽에 은은한 LED 조명으로 밤을 구현.
#   - 생활양식: 달의 낮(약 14일)과 밤의 주기를 인공적으로 조절하는 커다란 생활 리듬; 실내에서의 휴식 공간, 교육과 연구 시설이 긴 시간 열려 있음.
#   - 예술과 교육: 과학과 예술의 융합 공간이 많고, 우주 탐사 역사와 현재 연구가 함께 전시되는 공공 공간이 특징.
#
# 대표 랜드마크 아이디어
# - The Glass Spire: 돔의 중앙에 서 있는 유리 첨탑으로, 기상 관측, 데이터 시각화, 대형 이벤트의 무대 역할.
# - Mare Library: 달 표면의 데이터를 보존하고 인류의 우주 이주 역사를 기록하는 거대한 도서관.
# - Ice Gate: 물 아이스를 저장 및 가공하는 거대한 저장소이자 학술 연구의 출입구.
# - Seed Vault Dome: 식물 씨앗과 미생물 자원을 보존하는 국제 보존 시설.
# - Lunar Forum: 국제 협력 회의와 문화 교류를 위한 대규모 다목적 광장.
#
# 짧은 예시 시나리오(세계관 분위기 샘플)
# - 2030년대 말, Luna City의 에너지 위기가 닥치자 Lunar Assembly은 표면의 태양광 대형 패널 말단에 숨겨진 레드라인 공급망을 추적한다. 외부 기업의 독점 계약과 내부의 자원 분배 문제가 얽히며, 도시는 재생 에너지와 물 순환 시스템의 공용화 여부를 놓고 갈등에 빠진다. 한편 새로운 연구팀은 지하 망에서 발견한 고대 달 동굴의 미생물 생태계를 활용해 에너지 저장 문제를 해결하려 하지만, 그것이 국제 협력에 도전이 되기도 한다.
#
# 필요하신 분위기나 용도에 맞춰 조정해 드릴 수 있습니다
# - 어떤 톤이 좋으신가요? 사실적이고 낭만적인 SF, 하이테크-로우테크 사이의 균형, 다크 사이버펑크류 등.
# - 특정 매체용으로 원하시면(소설, 게임, 만화 등) 톤과 분량에 맞춰 더 구체화해 드리겠습니다.
# - 원하신다면 특정 작품이나 설정이 있다면 그에 맞춘 자세한 설정 파일도 만들어 드릴 수 있습니다.

# %% [markdown]
# 스트리밍 모드 종류
# - "values": 그래프의 전체 상태를 스트리밍
# - "updates": 각 노드의 업데이트만 스트리밍
# - "messages": 메시지 청크(토큰)를 실시간으로 스트리밍 ✅
