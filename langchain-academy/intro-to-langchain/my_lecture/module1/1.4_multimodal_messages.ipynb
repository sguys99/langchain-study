# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv("../../.env")
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this science-fiction setting, the capital of The Moon is Lunaris Prime.
#
# - Location: On the rim of Shackleton Crater in the lunar south polar region, where daylight can be harvested by vast solar farms.
# - Government: The Lunar Commonwealth’s capital, home to the main governing chambers, the Orbital Archives, and the Grand Observatory.
# - City vibe: A network of glass-domed districts and titanium spires rising from ice and regolith; water ice and Helium-3 industries power the city; levitated trams weave between habitats, and a ring of solar towers keeps the skyline eternally sunlit.
# - Notable features: The Ice Archive (a vast, crystal-clear chamber storing lunar ice and data), the Sun Gate (a solar-funnel for power, science, and ceremonies), and a bustling port for resupply and orbital traffic.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'frames_10fps_frame_00046.png', 'type': 'image/png', 'size': 1017383, 'content': <memory at 0x112f5ec80>, 'last_modified': datetime.datetime(2026, 1, 29, 16, 4, 26, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

print(img_b64)
# Out:
# ...

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "이 사진에 대해서 설명해줘."},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# 다음과 같은 항공사진처럼 보이는 도시 풍경입니다.
#
# - 상단에 길이 가로로 펼쳐져 있고 양쪽에 차들이 줄지어 주차되어 있습니다. 도로 양옆으로 주차된 차량들 덕에 도로의 한쪽이 주차 구역처럼 보입니다.
# - 중앙부에는 여러 줄의 주차 공간이 자리하고 있으며, 흰 선으로 구획이 촘촘하게 나뉘어 있습니다. 공간마다 차량이 빽빽이 주차되어 있습니다.
# - 주차 공간 사이를 가로지르는 도로에는 방향 화살표가 여러 개 보이며, 교통 흐름이 한 방향으로 정리되어 있습니다.
# - 주차 구역 주변에 장애인 주차 구역으로 보이는 표식도 몇 군데 보이고, 도로 중앙과 양쪽에 횡단보도와 차선 스트라이프가 반복적으로 배치되어 있습니다.
# - 상단의 도로 뒤쪽에는 금속 지붕을 가진 창고형 건물들이 일렬로 늘어져 있어 산업지대 같은 분위기를 풍깁니다.
# - 하단에는 큰 건물의 지붕이 보이며, 지붕에는 어두운 물 얼룩 같은 패턴이 있습니다. 전체적으로 색상은 회색 계열의 도로와 흰색 경계선이 돋보입니다.
# - 전반적으로 실용적이고 업무 지구 같은 분위기의 도시 풍경으로, 교통과 주차가 잘 정비된 구역임을 알 수 있습니다.
#
# 원하시면 이 사진을 바탕으로 미래의 수도를 설정한 짧은 이야기나 도시 묘사도 만들어 드릴게요.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import sounddevice as sd
#       2 from scipy.io.wavfile import write
#       3 import base64
#
# ModuleNotFoundError: No module named 'sounddevice'

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
